# %% [markdown]
# # Data Visualization using Matplotlib and Seaborn

# %% [markdown]
# # Matplotlib
# Matplotlib is one of the most popular Python packages used for data visualization. It is a cross-platform library for making 2D plots from data in arrays
#
# Seaborn
# ======
# Seaborn is a visualization library in Python. It is built on top of Matplotlib.
#
#
# Seaborn Vs Matplotlib
# ===============
# It is summarized that if Matplotlib “tries to make easy things easy and hard things possible”,
#
# Seaborn tries to make a well-defined set of hard things easy too.”
#
# Seaborn helps resolve the two major problems faced by Matplotlib
#
# 1. Default Matplotlib parameters
# 2. Working with data frames
#
#
# Important Features of Seaborn
# =============
# Seaborn is built on top of Python’s core visualization library Matplotlib. It is meant to serve as a complement, and not a replacement. However, Seaborn comes with some very important features. Let us see a few of them here.
#
# 1. Built in themes for styling matplotlib graphics
# 2. Visualizing univariate and bivariate data
# 3. Fitting in and visualizing linear regression models
# 4. Plotting statistical time series data
# 5. Seaborn works well with NumPy and Pandas data structures
# 6. It comes with built in themes for styling Matplotlib graphics

# %%
#Import the libraries
import matplotlib.pyplot as plt
import seaborn as sb
import pandas as pd
import numpy as np

# %% [markdown]
# # Simple plot - Matplotlib

# %%
x=[1,2,3,4]
y=[3,5,6,3]
plt.plot(x,y)
plt.show()

# %%
#adding label to the plot
plt.xlabel("X-values")
plt.ylabel("Y-values")
#adding tile to the plot
plt.title('Simple Plot')
#Line colour, doted line and Point mark shape --'g--o'
plt.plot(x,y,'g--o',label='Number')
#Legend to show value for which
plt.legend()
plt.show()

# %%
#multiple values in Single plot graph
x1=[3,4,5,6]
y1=[2,4,5,3]
#adding label to the plot
plt.xlabel("X-values")
plt.ylabel("Y-values")
#adding tile to the plot
plt.title('Simple Plot')
#Line colour, doted line and Point mark shape --'g--o'
plt.plot(x,y,'g--o',label='Number')
plt.plot(x1,y1,'r-s',label='Value')
#Legend to show value for which
plt.legend()
#Figure Size
plt.figure(figsize=(16,10),dpi=200)
plt.show()

# %%
#set limit to the axis
plt.xlim(0,8)
plt.ylim(1,8)
#adding label to the plot
plt.xlabel("X-values")
plt.ylabel("Y-values")
#adding tile to the plot
plt.title('Simple Plot')
#Line colour, doted line and Point mark shape --'g--o'
plt.plot(x,y,'g--o',label='Number')
plt.plot(x1,y1,'r-s',label='Value')
#Legend to show value for which
plt.legend()
#Figure Size
plt.figure(figsize=(16,10),dpi=200)
plt.show()

# %% [markdown]
# # Multiplots
#
# syntax for subplots
# ==========
# subplot(nrows, ncols, index, **kwargs)

# %%
#Multiplot with subplots
plt.subplot(1,3,1)
plt.plot(x,y,'g--o',label='Number')
plt.legend()
plt.subplot(1,4,4)
plt.plot(x1,y1,'r-s',label='Value')
#Legend to show value for which
plt.legend()
#Figure Size
plt.figure(figsize=(16,10),dpi=200)
plt.show()

# %%
fig = plt.figure()
a1 = fig.add_axes([0,0,1,1])
x = np.arange(1,11)
a1.plot(x,np.exp(x))
a1.set_ylabel('exp')
#it will twin axis of the plot
a2 = a1.twinx()
a2.plot(x, np.log(x),'ro-')
a2.set_ylabel('log')
fig.legend(labels = ('exp','log'),loc='upper left')
plt.show()

# %%
#Loading the dataset
df=pd.read_csv("FuelConsumptionCo2.csv")

# %%
df.head()
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# ...

# %%
#Group by value on enitre data set
df.groupby(["CYLINDERS"]).count()
# Out:
#            MODELYEAR  MAKE  MODEL  VEHICLECLASS  ENGINESIZE  TRANSMISSION  \
# CYLINDERS
# 3                  4     4      4             4           4             4
# 4                420   420    420           420         420           420
# 5                  9     9      9             9           9             9
# 6                356   356    356           356         356           356
# 8                252   252    252           252         252           252
# 10                 9     9      9             9           9             9
# 12                17    17     17            17          17            17
#
#            FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# CYLINDERS
# 3                 4                     4                    4
# 4               420                   420                  420
# 5                 9                     9                    9
# 6               356                   356                  356
# ...

# %%
#fuel type Group by value count on make
df.groupby(["FUELTYPE"])["MAKE"].count()
# Out:
# FUELTYPE
# D     27
# E     92
# X    514
# Z    434
# Name: MAKE, dtype: int64

# %%
#checking for null values
df.isnull().sum()
# Out:
# MODELYEAR                   0
# MAKE                        0
# MODEL                       0
# VEHICLECLASS                0
# ENGINESIZE                  0
# CYLINDERS                   0
# TRANSMISSION                0
# FUELTYPE                    0
# FUELCONSUMPTION_CITY        0
# FUELCONSUMPTION_HWY         0
# FUELCONSUMPTION_COMB        0
# FUELCONSUMPTION_COMB_MPG    0
# CO2EMISSIONS                0
# dtype: int64

# %% [markdown]
# # Bar Plot using Matplotlib
#
# A bar chart or bar graph is a chart or graph that presents categorical data with rectangular bars with heights or lengths proportional to the values that they represent. The bars can be plotted vertically or horizontally.
#
# A bar graph shows comparisons among discrete categories. One axis of the chart shows the specific categories being compared, and the other axis represents a measured value.
#
# Syntax:
# =====
# ax.bar(x, height, width, bottom, align)
#
# Parameters:
# =========
# 1. x     ---> sequence of scalars representing the x coordinates of the bars. align controls if x is the bar center (default) or left edge.
# 2. height	---> scalar or sequence of scalars representing the height(s) of the bars.
# 3. width	 ---> scalar or array-like, optional. the width(s) of the bars default 0.8
# 4. bottom	---> scalar or array-like, optional. the y coordinate(s) of the bars default None.
# 5. align	 ---> {‘center’, ‘edge’}, optional, default ‘center’

# %%
#barplot graph
fuel=df.loc[:,'FUELTYPE']
engine=df.loc[:,'CYLINDERS']
plt.figure(figsize=(4,5))
plt.bar(fuel,engine)

plt.show()

# %%
#horizontal barplot graph
fuel=df.loc[:,'FUELTYPE']
engine=df.loc[:,'ENGINESIZE']
plt.figure(figsize=(4,5))
plt.barh(fuel,engine)

plt.show()

# %%
#combined/multiple barplot
barWidth = 0.25
fuel=df.loc[:,'FUELTYPE']
cy=df.loc[:,'CYLINDERS']
plt.figure(figsize=(4,5))
plt.bar(fuel,cy,color ='r', width = barWidth, edgecolor ='grey', label ='cyd')
engine=df.loc[:,'ENGINESIZE']
plt.bar(fuel,engine,color ='g', width = barWidth, edgecolor ='grey', label ='eng')

plt.show()

# %% [markdown]
# # Pie Plot using matplotlib
#
# A Pie Chart can only display one series of data. Pie charts show the size of items (called wedge) in one data series, proportional to the sum of the items. The data points in a pie chart are shown as a percentage of the whole pie.
#
# Matplotlib API has a pie() function that generates a pie diagram representing data in an array. The fractional area of each wedge is given by x/sum(x). If sum(x)< 1, then the values of x give the fractional area directly and the array will not be normalized. Theresulting pie will have an empty wedge of size 1 - sum(x).
#
# The pie chart looks best if the figure and axes are square, or the Axes aspect is equal.
#
# Syntax:
# =======
#
#
# plt.pie(x, explode=None, labels=None, colors=None, autopct=None, pctdistance=0.6, shadow=False, labeldistance=1.1, startangle=None, radius=None, counterclock=True, wedgeprops=None, textprops=None, center=(0, 0), frame=False, rotatelabels=False, hold=None, data=None)
#
# Parameters:
# ========
# 1. x	--->array-like. The wedge sizes.
# 2. labels	--->list a sequence of strings providing the labels for each wedge.
# 3. Colors	--->A sequence of matplotlibcolorargs through which the pie chart will cycle. If None, will use the colors in the currently active cycle.
# 4. Autopct	--->string, used to label the wedges with their numeric value. The label will be placed inside the wedge. The format string will be fmt%pct.

# %%
#pieplot graph
fuel=df.loc[:,'FUELTYPE'].head(10)
engine=df.loc[:,'ENGINESIZE'].head(10)
plt.figure(figsize=(20,5))
plt.pie(engine,labels=fuel)
plt.show()

# %%
#Customized Pie Plot
# Creating dataset 
cars = ['AUDI', 'BMW', 'FORD',  
        'TESLA', 'JAGUAR', 'MERCEDES'] 
  
data = [23, 17, 35, 29, 12, 41] 
  
  
# Creating explode data 
explode = (0.1, 0.0, 0.2, 0.3, 0.0, 0.0) 
  
# Creating color parameters 
colors = ( "orange", "cyan", "brown", 
          "grey", "indigo", "beige") 
  
# Wedge properties 
wp = { 'linewidth' : 1, 'edgecolor' : "green" } 
  
# Creating autocpt arguments 
def func(pct, allvalues): 
    absolute = int(pct / 100.*np.sum(allvalues)) 
    return "{:.1f}%\n({:d} g)".format(pct, absolute) 
  
# Creating plot 
fig, ax = plt.subplots(figsize =(10, 7)) 
wedges, texts, autotexts = ax.pie(data,  
                                  autopct = lambda pct: func(pct, data), 
                                  explode = explode,  
                                  labels = cars, 
                                  shadow = True, 
                                  colors = colors, 
                                  startangle = 90, 
                                  wedgeprops = wp, 
                                  textprops = dict(color ="magenta")) 
  
# Adding legend 
ax.legend(wedges, cars, 
          title ="Cars", 
          loc ="center left", 
          bbox_to_anchor =(1, 0, 0.5, 1)) 
  
plt.setp(autotexts, size = 8, weight ="bold") 
ax.set_title("Customizing pie chart") 
  
# show plot 
plt.show()

# %%
#Nested Pie Plot  
# Creating dataset 
size = 6
cars = ['AUDI', 'BMW', 'FORD',  
        'TESLA', 'JAGUAR', 'MERCEDES'] 
  
data = np.array([[23, 16], [17, 23], 
                 [35, 11], [29, 33], 
                 [12, 27], [41, 42]]) 
  
# normalizing data to 2 pi 
norm = data / np.sum(data)*2 * np.pi 
  
# obtaining ordinates of bar edges 
left = np.cumsum(np.append(0,  
                           norm.flatten()[:-1])).reshape(data.shape) 
  
# Creating color scale 
cmap = plt.get_cmap("tab20c") 
outer_colors = cmap(np.arange(6)*4) 
inner_colors = cmap(np.array([1, 2, 5, 6, 9, 
                              10, 12, 13, 15, 
                              17, 18, 20 ])) 
  
# Creating plot 
fig, ax = plt.subplots(figsize =(10, 7), 
                       subplot_kw = dict(polar = True)) 
  
ax.bar(x = left[:, 0], 
       width = norm.sum(axis = 1), 
       bottom = 1-size, 
       height = size, 
       color = outer_colors,  
       edgecolor ='w', 
       linewidth = 1, 
       align ="edge") 
  
ax.bar(x = left.flatten(), 
       width = norm.flatten(), 
       bottom = 1-2 * size, 
       height = size, 
       color = inner_colors, 
       edgecolor ='w', 
       linewidth = 1, 
       align ="edge") 
  
ax.set(title ="Nested pie chart") 
ax.set_axis_off() 
  
# show plot 
plt.show()

# %% [markdown]
# # Histogram
#
# A histogram is an accurate representation of the distribution of numerical data. It is an estimate of the probability distribution of a continuous variable. It is a kind of bar graph.
#
#     1. Bin the range of values.
#     2. Divide the entire range of values into a series of intervals.
#     3. Count how many values fall into each interval.
# The bins are usually specified as consecutive, non-overlapping intervals of a variable.
#
# The matplotlib.pyplot.hist() function plots a histogram. It computes and draws the histogram of x.
#
# syntax:
# =====
#  plt.hist(x, bins=None, range=None, density=None, weights=None, cumulative=False, bottom=None, histtype='bar', align='mid', orientation='vertical', rwidth=None, log=False, color=None, label=None, stacked=False, normed=None, hold=None, data=None, **kwargs)
# Parameters:
#    =====
#    1. x	--->array or sequence of arrays
#    2. bins	--->integer or sequence or ‘auto’, optional
#
# Optional parameters:
#    ======
#    3. range -->The lower and upper range of the bins.
#    4. density -->If True, the first element of the return tuple will be the counts normalized to form a probability density
#    5. cumulative-->If True, then a histogram is computed where each bin gives the counts in that bin plus all bins for smaller values.
#    6. histtype	--->The type of histogram to draw. Default is ‘bar’
#
#         1) ‘bar’ is a traditional bar-type histogram. If multiple data are given the bars are arranged side by side.
#
#         2) ‘barstacked’ is a bar-type histogram where multiple data are stacked on top of each other.
#
#         3) ‘step’ generates a lineplot that is by default unfilled.
#
#         4) ‘stepfilled’ generates a lineplot that is by default filled.

# %%
#Histogram works on Continous data very well
engine=df.loc[:,'ENGINESIZE']
plt.hist(engine)
plt.title("Engine Size")
plt.show()

# %% [markdown]
# # Seaborn Histogram
#
# Syntax:
#     ===
#     sb.distplot(a, bins=None, hist=True, kde=True, rug=False, fit=None, hist_kws=None, kde_kws=None, rug_kws=None, fit_kws=None, color=None, vertical=False, norm_hist=False, axlabel=None, label=None, ax=None)

# %%
#Histogram Using Seaborn with kde by using this we can able to check the data is normally distributed.
sb.distplot(df['ENGINESIZE'],kde = True)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
#Histogram Using Seaborn with kde=False -- the representation of the kernel estimation plot will be removed 
#and only histogram is plotted.
sb.distplot(df['ENGINESIZE'],kde = False)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# # Kernel Density Estimation (KDE)
# It is a way to estimate the probability density function of a continuous random variable. It is used for non-parametric analysis.
#
# Setting the hist flag to False in distplot will yield the kernel density estimation plot.

# %%
sb.distplot(df['ENGINESIZE'],hist = False)
plt.show()

# %% [markdown]
# # Scatter plot in Matplotlib
#
# Scatter plots are used to plot data points on horizontal and vertical axis in the attempt to show how much one variable is affected by another. Each row in the data table is represented by a marker the position depends on its values in the columns set on the X and Y axes. A third variable can be set to correspond to the color or size of the markers, thus adding yet another dimension to the plot.

# %%
#Scatterplot graph
fuel=df.loc[:,'FUELTYPE']
engine=df.loc[:,'CYLINDERS']
plt.figure(figsize=(5,6))
plt.scatter(fuel,engine)
plt.xlabel("Fuel")
plt.ylabel("Cylinder")
plt.title("Fuel VS Cylinder")
plt.legend()
plt.show()

# %% [markdown]
# # Seaborn - Visualizing Pairwise Relationship
# Datasets under real-time study contain many variables. In such cases, the relation between each and every variable should be analyzed. Plotting Bivariate Distribution for (n,2) combinations will be a very complex and time taking process.
#
# To plot multiple pairwise bivariate distributions in a dataset, you can use the pairplot() function. This shows the relationship for (n,2) combination of variable in a DataFrame as a matrix of plots and the diagonal plots are the univariate plots.
#
# Syntax:
#     ===
# sb.pairplot(data, hue=None, hue_order=None, palette=None, vars=None, x_vars=None, y_vars=None, kind='scatter', diag_kind='hist', markers=None, size=2.5, aspect=1, dropna=True, plot_kws=None, diag_kws=None, grid_kws=None)
#
# Parameters:
#     ====
#  1. 	data--->Dataframe
#
#  2. 	hue--->Variable in data to map plot aspects to different colors.
#
#  3. 	palette--->Set of colors for mapping the hue variable
#
#  4. 	kind--->Kind of plot for the non-identity relationships. {‘scatter’, ‘reg’}
#
#  5. 	diag_kind--->Kind of plot for the diagonal subplots. {‘hist’, ‘kde’}

# %%
#Relationship between each data feature related to each other using hist
sb.pairplot(df)

# %%
#Relationship between each data feature related to each other using kde
sb.pairplot(df,diag_kind='kde')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %% [markdown]
# # Box Plot
#
# A box plot which is also known as a whisker plot displays a summary of a set of data containing the minimum, first quartile, median, third quartile, and maximum. In a box plot, we draw a box from the first quartile to the third quartile. A vertical line goes through the box at the median. The whiskers go from each quartile to the minimum or maximum.
#
# ![image.png](attachment:image.png)
#
# In descriptive statistics, a box plot is a method for graphically depicting groups of numerical data through their quartiles. Box plots may also have lines extending vertically from the boxes (whiskers) indicating variability outside the upper and lower quartiles, hence the terms box-and-whisker plot and box-and-whisker diagram. Outliers may be plotted as individual points.
#
# Syntax:
# =======
# plt.boxplot(x, notch=None, sym=None, vert=None, whis=None, positions=None, widths=None, patch_artist=None, bootstrap=None, usermedians=None, conf_intervals=None, meanline=None, showmeans=None, showcaps=None, showbox=None, showfliers=None, boxprops=None, labels=None, flierprops=None, medianprops=None, meanprops=None, capprops=None, whiskerprops=None, manage_xticks=True, autorange=False, zorder=None, hold=None, data=None)

# %%
#Box Plot in matplotlib
engine=df.loc[:,'ENGINESIZE']
plt.boxplot(engine)
plt.title("Engine Size")
plt.show()

# %% [markdown]
# # Boxplot in Seaborn
#
# Syntax:
#     ==
#     sb.boxplot(x=None, y=None, hue=None, data=None, order=None, hue_order=None, orient=None, color=None, palette=None, saturation=0.75, width=0.8, dodge=True, fliersize=5, linewidth=None, whis=1.5, notch=False, ax=None, **kwargs)

# %%
#Blox Plot using seaborn
engine=df.loc[:,'ENGINESIZE']
sb.boxplot(engine)
plt.title("Engine Size")
plt.show()

# %% [markdown]
# # Violin PLot
#
# Violin plots are similar to box plots, except that they also show the probability density of the data at different values. These plots include a marker for the median of the data and a box indicating the interquartile range, as in the standard box plots. Overlaid on this box plot is a kernel density estimation. Like box plots, violin plots are used to represent comparison of a variable distribution (or sample distribution) across different "categories".

# %%
#Blox Plot using matplotlib
engine=df.loc[:,'ENGINESIZE']
plt.violinplot(engine)
plt.title("Engine Size")
plt.figure(figsize=(6,10))
plt.show()

# %%
#Blox Plot using seaborn
engine=df.loc[:,'ENGINESIZE']
sb.violinplot(engine)
plt.title("Engine Size")
plt.figure(figsize=(6,10))
plt.show()

# %% [markdown]
# # Seaborn - Distribution of Observations using Box plot and violin plot
#
#
# In categorical scatter plots which we dealt in the previous chapter, the approach becomes limited in the information it can provide about the distribution of values within each category. Now, going further, let us see what can facilitate us with performing comparison with in categories.
#
# Box Plots
# =========
# Boxplot is a convenient way to visualize the distribution of data through their quartiles.
#
# Box plots usually have vertical lines extending from the boxes which are termed as whiskers. These whiskers indicate variability outside the upper and lower quartiles, hence Box Plots are also termed as box-and-whisker plot and box-and-whisker diagram. Any Outliers in the data are plotted as individual points.
#
#
# Violin Plots
# ========
# Violin Plots are a combination of the box plot with the kernel density estimates. So, these plots are easier to analyze and understand the distribution of the data.

# %%
#using Boxplot in Seaborn
sb.boxplot(x='FUELTYPE',y='ENGINESIZE',data=df)
plt.show()

# %%
#using violinplot in Seaborn
sb.violinplot(x='FUELTYPE',y='ENGINESIZE',data=df)
plt.show()

# %% [markdown]
# # Seaborn - Plotting Categorical Data
#
# scatter plots, hexbin plots and kde plots which are used to analyze the continuous variables. These plots are not suitable when the variable is categorical.
#
# 1.stripplot()
# ==========
# stripplot() is used when one of the variable under study is categorical. It represents the data in sorted order along any one of the axis.
#
# syntax:
# ======
# sb.stripplot(x=None, y=None, hue=None, data=None, order=None, hue_order=None, jitter=False, dodge=False, orient=None, color=None, palette=None, size=5, edgecolor='gray', linewidth=0, ax=None, **kwargs)

# %%
#Striplot in Seaborn
sb.stripplot(x='FUELTYPE',y='ENGINESIZE',data=df)
plt.show()

# %% [markdown]
# In the above plot, we can clearly see the difference of enginesize in each Fueltype. But, the major problem with the above scatter plot is that the points on the scatter plot are overlapped.
#
# We use the ‘Jitter’ parameter to handle this kind of scenario.Jitter adds some random noise to the data. This parameter will adjust the positions along the categorical axis.

# %%
#Striplot in Seaborn using jitter -- True

sb.stripplot(x='FUELTYPE',y='ENGINESIZE',data=df,jitter=True)
plt.show()

# %% [markdown]
# # 2.Swarmplot()
# Another option which can be used as an alternate to ‘Jitter’ is function swarmplot(). This function positions each point of scatter plot on the categorical axis and thereby avoids overlapping points
#
# Syntax:
# ======
# sb.swarmplot(x=None, y=None, hue=None, data=None, order=None, hue_order=None, dodge=False, orient=None, color=None, palette=None, size=5, edgecolor='gray', linewidth=0, ax=None, **kwargs)

# %%
#swarmplot  in seaborn
sb.swarmplot(x='FUELTYPE',y='ENGINESIZE',data=df)
plt.show()

# %% [markdown]
# # Seaborn - Statistical Estimation
#
# In most of the situations, we deal with estimations of the whole distribution of the data. But when it comes to central tendency estimation, we need a specific way to summarize the distribution. Mean and median are the very often used techniques to estimate the central tendency of the distribution.
#
# In all the plots that we learnt in the above section, we made the visualization of the whole distribution. Now, let us discuss regarding the plots with which we can estimate the central tendency of the distribution.
#
# Bar Plot
# ========
# The barplot() shows the relation between a categorical variable and a continuous variable. The data is represented in rectangular bars where the length the bar represents the proportion of the data in that category.
#
# Bar plot represents the estimate of central tendency.

# %%
#barplot in seaborn for statistical estimation
sb.barplot(x = "CYLINDERS", y = "ENGINESIZE", hue = "FUELTYPE", data = df)
plt.show()

# %% [markdown]
# # Point Plots
# Point plots serve same as bar plots but in a different style. Rather than the full bar, the value of the estimate is represented by the point at a certain height on the other axis.
#
# Syntax:
# ======
# sb.pointplot(x=None, y=None, hue=None, data=None, order=None, hue_order=None, estimator=<function mean at 0x00000273C783AAE8>, ci=95, n_boot=1000, units=None, markers='o', linestyles='-', dodge=False, join=True, scale=1, orient=None, color=None, palette=None, errwidth=None, capsize=None, ax=None, **kwargs)

# %%
#Pointplot in seaborn for statistical estimation
sb.pointplot(x = "CYLINDERS", y = "ENGINESIZE", hue = "FUELTYPE", data = df)
plt.show()

# %% [markdown]
# # Multi Panel Categorical Plots
# # Factorplot
# Factorplot draws a categorical plot on a FacetGrid. Using ‘kind’ parameter we can choose the plot like boxplot, violinplot, barplot and stripplot. FacetGrid uses pointplot by default.
#
# Syntax:
# ======
#
# sb.factorplot(x=None, y=None, hue=None, data=None, row=None, col=None, col_wrap=None, estimator=<function mean at 0x00000273C783AAE8>, ci=95, n_boot=1000, units=None, order=None, hue_order=None, row_order=None, col_order=None, kind='point', size=4, aspect=1, orient=None, color=None, palette=None, legend=True, legend_out=True, sharex=True, sharey=True, margin_titles=False, facet_kws=None, **kwargs)

# %%
#factorplot in seaborn with pointplot by default
sb.factorplot(x = "CYLINDERS", y = "ENGINESIZE", hue = "FUELTYPE", data = df)
plt.show()

# %%
#factorplot in seaborn by using kind we can change the plot 
sb.factorplot(x = "CYLINDERS", y = "ENGINESIZE", hue = "FUELTYPE", data = df,kind='box')
plt.show()

# %% [markdown]
# # Seaborn - Linear Relationships
#
# While building the regression models, we often check for multicollinearity, where we had to see the correlation between all the combinations of continuous variables and will take necessary action to remove multicollinearity if exists. In such cases, the following techniques helps.
#
# Functions to Draw Linear Regression Models
# =============
# There are two main functions in Seaborn to visualize a linear relationship determined through regression.
# These functions are regplot() and lmplot().
#
# Regplot vs lmplot
# ===========
# Regplot
# ======
# accepts the x and y variables in a variety of formats including simple numpy arrays, pandas Series objects, or as references to variables in a pandas DataFrame
#
# lmplot
# ======
# has data as a required parameter and the x and y variables must be specified as strings. This data format is called “long-form” data

# %%
#Dataset
df.head()
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# ...

# %%
#Regplot
sb.regplot(x = "FUELCONSUMPTION_CITY", y = "CO2EMISSIONS", data = df)
plt.show()

# %%
#lmplot
sb.lmplot(x = "FUELCONSUMPTION_CITY", y = "CO2EMISSIONS", data = df)
plt.show()

# %% [markdown]
# # 3D Plots
#
# contour3D
# ========
# The ax.contour3D() function creates three-dimensional contour plot. It requires all the input data to be in the form of two-dimensional regular grids, with the Z-data evaluated at each point. Here, we will show a three-dimensional contour diagram of a three-dimensional sinusoidal function.

# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
def f(x, y):
   return np.sin(np.sqrt(x ** 2 + y ** 2))

x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 50, cmap='binary')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('3D contour')
plt.show()

# %% [markdown]
# # Wireframe plot
# It takes a grid of values and projects it onto the specified three-dimensional surface, and can make the resulting three-dimensional forms quite easy to visualize.

# %%
#Wireframe PLot
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_wireframe(X, Y, Z, color='orange')
ax.set_title('wireframe')
plt.show()

# %% [markdown]
# # Surface plot
#
# It shows a functional relationship between a designated dependent variable (Y), and two independent variables (X and Z). The plot is a companion plot to the contour plot. A surface plot is like a wireframe plot, but each face of the wireframe is a filled polygon. This can aid perception of the topology of the surface being visualized. The plot_surface() function x,y and z as arguments.

# %%
#Surface PLot
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, color='orange')
ax.set_title('wireframe')
plt.show()
