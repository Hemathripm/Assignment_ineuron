# %% [markdown]
# # Data Pre-Processing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# # Read Data using JSON
# Syntax:
# ======
#  pd.read_json(path_or_buf=None, orient=None, typ='frame', dtype=True, convert_axes=True, convert_dates=True, keep_default_dates=True, numpy=False, precise_float=False, date_unit=None, encoding=None, lines=False, chunksize=None, compression='infer')

# %%
#For Example for read_json
df_json=pd.read_json("inp.json")
df_json
# Out:
#    ID      Name  Salary   StartDate        Dept
# 0   1      Rick  623.30    1/1/2012          IT
# 1   2       Dan  515.20   9/23/2013  Operations
# 2   3  Michelle  611.00  11/15/2014          IT
# 3   4      Ryan  729.00   5/11/2014          HR
# 4   5      Gary  843.25   3/27/2015     Finance
# 5   6      Nina  578.00   5/21/2013          IT
# 6   7     Simon  632.80   7/30/2013  Operations
# 7   8      Guru  722.50   6/17/2014     Finance

# %% [markdown]
# # Read Data using xls or xlsx
#
# syntax:
#     ===
#     pd.read_excel(io, sheet_name=0, header=0, names=None, index_col=None, usecols=None, squeeze=False, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skiprows=None, nrows=None, na_values=None, parse_dates=False, date_parser=None, thousands=None, comment=None, skipfooter=0, convert_float=True, **kwds)

# %%
df_exc=pd.read_excel("cara.xlsx")
df_exc.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2

# %% [markdown]
# # Read data using CSV in pandas
#
# Syntax:
# =======
# pd.read_csv(filepath_or_buffer, sep=',', delimiter=None, header='infer', names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, iterator=False, chunksize=None, compression='infer', thousands=None, decimal=b'.', lineterminator=None, quotechar='"', quoting=0, escapechar=None, comment=None, encoding=None, dialect=None, tupleize_cols=None, error_bad_lines=True, warn_bad_lines=True, skipfooter=0, doublequote=True, delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None)

# %%
#for Example we are using read_csv
df=pd.read_csv("wine.csv")

# %%
#to display the records
df.head(2)
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
#
#     designation  points  price           province region_1 region_2  \
# 0  Vulkà Bianco      87    NaN  Sicily & Sardinia     Etna      NaN
# 1      Avidagos      87   15.0              Douro      NaN      NaN
#
#      taster_name taster_twitter_handle  \
# 0  Kerin O’Keefe          @kerinokeefe
# 1     Roger Voss            @vossroger
#
#                                            title         variety  \
# 0              Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1  Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
#
#                 winery
# 0              Nicosia
# 1  Quinta dos Avidagos

# %%
#showing the column names
df.columns
# Out:
# Index(['Unnamed: 0', 'country', 'description', 'designation', 'points',
#        'price', 'province', 'region_1', 'region_2', 'taster_name',
#        'taster_twitter_handle', 'title', 'variety', 'winery'],
#       dtype='object')

# %%
#how to replace the columns in pandas
names=df.columns.tolist()
names[0]='Number'
names
df.columns=names

# %%
df.columns
# Out:
# Index(['Number', 'country', 'description', 'designation', 'points', 'price',
#        'province', 'region_1', 'region_2', 'taster_name',
#        'taster_twitter_handle', 'title', 'variety', 'winery'],
#       dtype='object')

# %%
#now columns are changed
df.head(1)
# Out:
#    Number country                                        description  \
# 0       0   Italy  Aromas include tropical fruit, broom, brimston...
#
#     designation  points  price           province region_1 region_2  \
# 0  Vulkà Bianco      87    NaN  Sicily & Sardinia     Etna      NaN
#
#      taster_name taster_twitter_handle                              title  \
# 0  Kerin O’Keefe          @kerinokeefe  Nicosia 2013 Vulkà Bianco  (Etna)
#
#        variety   winery
# 0  White Blend  Nicosia

# %%
#how set index as column values
#like this is tempoarary
df.set_index('Number').head(1)
# Out:
#        country                                        description  \
# Number
# 0        Italy  Aromas include tropical fruit, broom, brimston...
#
#          designation  points  price           province region_1 region_2  \
# Number
# 0       Vulkà Bianco      87    NaN  Sicily & Sardinia     Etna      NaN
#
#           taster_name taster_twitter_handle  \
# Number
# 0       Kerin O’Keefe          @kerinokeefe
#
#                                     title      variety   winery
# Number
# 0       Nicosia 2013 Vulkà Bianco  (Etna)  White Blend  Nicosia

# %%
#checking the changes
df.head(1)
# Out:
#    Number country                                        description  \
# 0       0   Italy  Aromas include tropical fruit, broom, brimston...
#
#     designation  points  price           province region_1 region_2  \
# 0  Vulkà Bianco      87    NaN  Sicily & Sardinia     Etna      NaN
#
#      taster_name taster_twitter_handle                              title  \
# 0  Kerin O’Keefe          @kerinokeefe  Nicosia 2013 Vulkà Bianco  (Etna)
#
#        variety   winery
# 0  White Blend  Nicosia

# %%
#to do this permanent
df=df.set_index('Number')
df.head(1)
# Out:
#        country                                        description  \
# Number
# 0        Italy  Aromas include tropical fruit, broom, brimston...
#
#          designation  points  price           province region_1 region_2  \
# Number
# 0       Vulkà Bianco      87    NaN  Sicily & Sardinia     Etna      NaN
#
#           taster_name taster_twitter_handle  \
# Number
# 0       Kerin O’Keefe          @kerinokeefe
#
#                                     title      variety   winery
# Number
# 0       Nicosia 2013 Vulkà Bianco  (Etna)  White Blend  Nicosia

# %%
#Skewness of the data 
#if value greater than 0 then it is right skewed
df.skew()
# Out:
# points     0.045921
# price     18.000957
# dtype: float64

# %%
df['region_2'].value_counts()
# Out:
# Central Coast        11065
# Sonoma                9028
# Columbia Valley       8103
# Napa                  6814
# Willamette Valley     3423
# California Other      2663
# Finger Lakes          1777
# Sierra Foothills      1462
# Napa-Sonoma           1169
# Central Valley        1062
# Southern Oregon        917
# Oregon Other           727
# Long Island            680
# North Coast            584
# Washington Other       534
# South Coast            272
# New York Other         231
# Name: region_2, dtype: int64

# %%
df.region_2.value_counts(normalize=True)
# Out:
# Central Coast        0.219061
# Sonoma               0.178733
# Columbia Valley      0.160421
# Napa                 0.134901
# Willamette Valley    0.067767
# California Other     0.052721
# Finger Lakes         0.035180
# Sierra Foothills     0.028944
# Napa-Sonoma          0.023143
# Central Valley       0.021025
# Southern Oregon      0.018154
# Oregon Other         0.014393
# Long Island          0.013462
# North Coast          0.011562
# Washington Other     0.010572
# South Coast          0.005385
# New York Other       0.004573
# Name: region_2, dtype: float64

# %%
df.nunique()
# Out:
# country                      43
# description              119955
# designation               37979
# points                       21
# price                       390
# province                    425
# region_1                   1229
# region_2                     17
# taster_name                  19
# taster_twitter_handle        15
# title                    118840
# variety                     707
# winery                    16757
# dtype: int64

# %%
df.isnull().sum()
# Out:
# country                     63
# description                  0
# designation              37465
# points                       0
# price                     8996
# province                    63
# region_1                 21247
# region_2                 79460
# taster_name              26244
# taster_twitter_handle    31213
# title                        0
# variety                      1
# winery                       0
# dtype: int64

# %%
df.count()
# Out:
# country                  129908
# description              129971
# designation               92506
# points                   129971
# price                    120975
# province                 129908
# region_1                 108724
# region_2                  50511
# taster_name              103727
# taster_twitter_handle     98758
# title                    129971
# variety                  129970
# winery                   129971
# dtype: int64

# %% [markdown]
# # Data Exploration and Preparation

# %%
#Data Set 
df_tra = pd.read_csv('house_train.csv')

# %%
df_tra.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#Removing the columns which is having greater than 260 "NaN" value in each column 
df_na=pd.DataFrame([df_tra.isnull().sum()]).T
#renaming the columns
df_na=df_na.rename(columns={0:"data"})
#Sort the data
df_na.sort_values(by='data',ascending=False).head()
# Out:
#              data
# PoolQC       1453
# MiscFeature  1406
# Alley        1369
# Fence        1179
# FireplaceQu   690

# %%
#Reset index into rows
df_na.reset_index(inplace=True)
df_na.head()
# Out:
#         index  data
# 0          Id     0
# 1  MSSubClass     0
# 2    MSZoning     0
# 3     LotArea     0
# 4      Street     0

# %%
#filter values
isna_100=df_na>100

# %%
#filter mapping to values to get the data
df_na1=df_na[isna_100]
df_na1.head()
# Out:
#               data
# Id             NaN
# MSSubClass     NaN
# MSZoning       NaN
# LotFrontage  259.0
# LotArea        NaN

# %%
#replace 
df_na=df_na1.dropna()

# %%
#Index values
x=df_na.index.values
x
# Out:
# array(['LotFrontage', 'Alley', 'FireplaceQu', 'PoolQC', 'Fence',
#        'MiscFeature'], dtype=object)

# %%
#Drop NA present columns
df_tra=df_tra.drop(columns=['LotFrontage', 'Alley', 'FireplaceQu', 'PoolQC', 'Fence','MiscFeature'])
df_tra.head()
# Out:
#    Id  MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 0   1          60       RL     8450   Pave      Reg         Lvl    AllPub
# 1   2          20       RL     9600   Pave      Reg         Lvl    AllPub
# 2   3          60       RL    11250   Pave      IR1         Lvl    AllPub
# 3   4          70       RL     9550   Pave      IR1         Lvl    AllPub
# 4   5          60       RL    14260   Pave      IR1         Lvl    AllPub
#
#   LotConfig LandSlope    ...    EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 0    Inside       Gtl    ...                0         0           0        0
# 1       FR2       Gtl    ...                0         0           0        0
# 2    Inside       Gtl    ...                0         0           0        0
# 3    Corner       Gtl    ...              272         0           0        0
# 4       FR2       Gtl    ...                0         0           0        0
#
# ...

# %%
#check sum of NA values
df_tra.isnull().sum().head()
# Out:
# Id            0
# MSSubClass    0
# MSZoning      0
# LotArea       0
# Street        0
# dtype: int64

# %%
df_tra.dropna(inplace=True)

# %%
df_tra.head()
# Out:
#    Id  MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 0   1          60       RL     8450   Pave      Reg         Lvl    AllPub
# 1   2          20       RL     9600   Pave      Reg         Lvl    AllPub
# 2   3          60       RL    11250   Pave      IR1         Lvl    AllPub
# 3   4          70       RL     9550   Pave      IR1         Lvl    AllPub
# 4   5          60       RL    14260   Pave      IR1         Lvl    AllPub
#
#   LotConfig LandSlope    ...    EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 0    Inside       Gtl    ...                0         0           0        0
# 1       FR2       Gtl    ...                0         0           0        0
# 2    Inside       Gtl    ...                0         0           0        0
# 3    Corner       Gtl    ...              272         0           0        0
# 4       FR2       Gtl    ...                0         0           0        0
#
# ...

# %%
df_tra['SaleCondition'].value_counts()
# Out:
# Normal     1104
# Partial     120
# Abnorml      86
# Family       20
# Alloca        7
# AdjLand       1
# Name: SaleCondition, dtype: int64
